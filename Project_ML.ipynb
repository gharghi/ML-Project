# %%
import pandas as pd
import numpy as np
import scipy as sp
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels as sm
import os
import csv
from zipfile import ZipFile
from datetime import datetime

# %%
Test=pd.read_excel(r'C:\Users\HP\Desktop\Data Science\Machine Learning\Projeto\Test.xlsx',sheet_name='Sheet1')
Train=pd.read_excel(r'C:\Users\HP\Desktop\Data Science\Machine Learning\Projeto\Train.xlsx',sheet_name='Sheet1')

# %%
Test
# Out:
#        CITIZEN_ID                    Name            Birthday  \
# 0           34886            Mr. Dan Kerr         May 13,2012
# 1           34887       Miss Olivia Grant       August 9,2014
# 2           34888      Mr. Trevor Simpson         May 23,2020
# 3           34889         Mr. David Clark       April 15,2016
# 4           34890       Mr. Gavin Lambert       April 22,2011
# ...           ...                     ...                 ...
# 10095       44981      Mr. Victor Cornish        June 12,2012
# 10096       44982      Mr. Benjamin Jones       March 26,2000
# 10097       44983  Miss Jennifer Rampling     January 28,2022
# 10098       44984  Miss Kimberly Rampling        July 22,2024
# 10099       44985         Mr. Eric Newman   September 27,1993
#
#       Native Continent Marital Status    Lives with  Base Area  \
# 0               Europe        Married          Wife  Northbury
# 1               Europe         Single  Other Family  Northbury
# ...

# %%
Train
# Out:
#        CITIZEN_ID                   Name          Birthday Native Continent  \
# 0           12486        Mr. Adam Glover       July 1,2003           Europe
# 1           12487   Mr. Cameron McDonald   January 25,2006           Europe
# 2           12488     Mr. Keith Davidson       May 10,2009           Europe
# 3           12489     Mr. Alexander Gill     March 25,1985           Europe
# 4           12490         Mr. Neil Piper       May 29,2015           Europe
# ...           ...                    ...               ...              ...
# 22395       34881        Mrs. Lisa Alsop     March 15,2023           Europe
# 22396       34882     Mr. Julian Coleman      March 7,2025           Europe
# 22397       34883     Miss Amelia Walker      July 20,2022           Europe
# 22398       34884  Mr. Justin Sutherland      June 11,2011           Europe
# 22399       34885      Mr. Joseph Murray    October 2,2026             Asia
#
# ...
